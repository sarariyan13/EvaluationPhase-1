# %% [markdown]
# # EVALUATION-PHASE-1

# %% [markdown]
# # NAME OF PROJECT: AVOCADO PRICE PREDICTION

# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Downloading the avocado csv file from Github into the PC and uploading into Jupyter Notebook and calling it here using pd.read_csv

# %%
df=pd.read_csv("avocado.csv")
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...

# %%
df.shape
# Out:
# (18249, 14)

# %% [markdown]
# The avocado dataset contains 18249 rows and 14 columns in total, out of which one is target/label.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
There are a total of 14 columns. Price is considered as Target/Label. Other variables include Date, AveragePrice, TotalVolumen,
4046, 4225, 4770, Total Bags, Small Bags, Large Bags, XLarge Bags, type, year and region.

# %%
df.columns.to_list()
# Out:
# ['Unnamed: 0',
#  'Date',
#  'AveragePrice',
#  'Total Volume',
#  '4046',
#  '4225',
#  '4770',
#  'Total Bags',
#  'Small Bags',
#  'Large Bags',
#  'XLarge Bags',
#  'type',
#  'year',
#  'region']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %% [markdown]
# The info() functions gives us the information of the datatypes in the dataset. So we have 3 datatypes, integer, object and float
# datatype. Date is showing as object, which we will convert to datetime format. There are 18249 non-null values in all columns.
# The memory usage is 1.9+ MB and range of dataset is 0 to 18248.

# %% [markdown]
# # CHECKING FOR MISSING VALUES

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Both the df.isnull() method and heatmap show that there no missing values. The map is of uniform color at value 0.00.

# %% [markdown]
# # CALCULATING THE VALUE.COUNTS() FOR EACH VARIABLE TO CHECK WIDE SPACES OR NULL VALUES

# %%
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 0     432
# 7     432
# 1     432
# 11    432
# 9     432
# 8     432
# 10    432
# 6     432
# 5     432
# 4     432
# 3     432
# 2     432
# 41    324
# 34    324
# 35    324
# 36    324
# 37    324
# 38    324
# 39    324
# 40    324
# 47    324
# 42    324
# 43    324
# 44    324
# 45    324
# 46    324
# 32    324
# 48    324
# 49    324
# 50    324
# 33    324
# 26    324
# 31    324
# 30    324
# 12    324
# 13    324
# 14    324
# 15    324
# 16    324
# 17    324
# 18    324
# 19    324
# 20    324
# 21    324
# 22    324
# 23    324
# 24    324
# 25    324
# 27    324
# 28    324
# 29    324
# 51    322
# 52    107
# Name: Unnamed: 0, dtype: int64
#
#
# 2015-12-27    108
# 2017-12-24    108
# 2017-12-10    108
# 2017-12-03    108
# 2017-11-26    108
#              ...
# 2016-11-06    108
# 2018-01-07    108
# 2017-06-18    107
# 2017-06-25    107
# 2015-12-06    107
# Name: Date, Length: 169, dtype: int64
#
#
# 1.15    202
# 1.18    199
# 1.08    194
# 1.26    193
# ...

# %% [markdown]
# we can clearly see that there are no wide spaces or null or missing values in the dataset.

# %%
df.nunique().to_frame("Avocado Unique Values")
# Out:
#               Avocado Unique Values
# Unnamed: 0                       53
# Date                            169
# AveragePrice                    259
# Total Volume                  18237
# 4046                          17702
# 4225                          18103
# 4770                          12071
# Total Bags                    18097
# Small Bags                    17321
# Large Bags                    15082
# XLarge Bags                    5588
# type                              2
# year                              4
# region                           54

# %%
df['AveragePrice'].nunique()
# Out:
# 259

# %%
#df = pd.read_csv('temp[1].csv', parse_dates=['Date']) Showing error, so tried using the next method
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1063: UserWarning: Parsing '30-06-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1063: UserWarning: Parsing '13-07-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1063: UserWarning: Parsing '14-07-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
df['Date']=pd.to_datetime(df.Date)

# %%
df['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# # The AveragePrice is the target/lable and has 259 unique values and total number or rows is 18249. The AveragePrice variable also has float values. So we can consider this as a Regression based problem. AveragePrice can be predicted using LinearRegression as well as other regression based algorithms.

# %% [markdown]
# # STATISTICAL DATA SUMMARY

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %% [markdown]
# OBSERVATIONS:
# 1.  Count of the rows is equal, indicating no missing values.
# 2.  There are no negative values in the dataset, which is good and the data summary is excellent.
# 3.  Skewness:
#     Mean is greater than median for Unnamed, AveragePrice, Total Volume, 4225,4770, Large Bags, XLarge Bags, and year. So
#     here, the variables show right skewness.
#     Mean is lesser than median in 4046, Total Bags, and Small Bags. So here we can see left skewness for these variables.
# 4.  Standard deviation is less than 1 for Average Price and year.
# 5.  There is difference between 75% and max values for all variables except for Total Bags, there is minor difference.
#     Outliers will be found in the dataset.
# 6.  Minimum values for all the columns is 0 except for AveragePrice and Total Volume and date columns.
#     We can also note 25% values for all the variables respectively.

# %%
plt.figure(figsize=(22, 10))
sns.heatmap(df.describe(), annot=True, fmt='0.2f', linewidth=0.2, linecolor='black', cmap='Spectral')
plt.xlabel('Figure', fontsize=14)
plt.ylabel("Featuire_name', fontsize=20")
plt.title("Descriptive Graph", fontsize=30)
plt.show()

# %% [markdown]
# The heatmap also shows the same findings as the df.describe() method. Total volume shows a blue color indicating highest value.
# We can see the row counts are equal. Also mean, median, standard deviation, minimum values, max values and 75% values.

# %% [markdown]
# We can dropped Unnamed column as we do not have any information

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %% [markdown]
# # GRAPHICAL ANALYSIS

# %% [markdown]
# # Univariate Analysis

# %%
sns.countplot(x='type', data=df)
df['type'].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %% [markdown]
# There are 9126 conventional avocados and 9123 organic ones.

# %%
sns.countplot(x='region', data=df)
df['region'].value_counts()
# Out:
# Albany                 338
# Sacramento             338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# Pittsburgh             338
# Plains                 338
# Portland               338
# RaleighGreensboro      338
# RichmondNorfolk        338
# Roanoke                338
# SanDiego               338
# Atlanta                338
# SanFrancisco           338
# Seattle                338
# SouthCarolina          338
# SouthCentral           338
# Southeast              338
# Spokane                338
# StLouis                338
# Syracuse               338
# Tampa                  338
# TotalUS                338
# West                   338
# NewYork                338
# NewOrleansMobile       338
# Nashville              338
# Midsouth               338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# BuffaloRochester       338
# ...

# %% [markdown]
# So, there are 54 different regions in the avocado dataset.

# %% [markdown]
# # HISTOGRAMS

# %%
plt.figure(figsize = (25,50), facecolor = 'white')
plotnumber = 1

for column in df:
    if plotnumber <=17:
        ax = plt.subplot(10,2,plotnumber)
        sns.histplot(df[column], color = 'blue')
        plt.xlabel(column,fontsize=20)
        
    plotnumber += 1
plt.show()

# %%
Date, region, type have almost more or less equal counts. All the numerical columns have a right=-sided skewed curve. Year
has a near normal curve

# %% [markdown]
# # Splitting categorical and numerical datatypes

# %%
categorical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]=="object":
        categorical_col.append(i)
print("Categorical columns:", categorical_col)
# Out:
# Categorical columns: ['type', 'region']

# %%
numerical_col=[]    
for i in df.dtypes.index:
    if df.dtypes[i]!="object":
        numerical_col.append(i)
print("Numerical columns:", numerical_col)
# Out:
# Numerical columns: ['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'year']

# %%
df.set_index('Date', inplace=True)
df
# Out:
#             AveragePrice  Total Volume     4046       4225    4770  \
# Date
# 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...                  ...           ...      ...        ...     ...
# 2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# ...

# %%
df.hist(bins=20, figsize=(12, 12))
plt.show()

# %%
We can see that except year column, all the numerical columns have a right_sided skewed curve only

# %%
sns.set_palette('gist_rainbow_r')
plt.figure(figsize=(20,20), facecolor='white')
plotnumber =1
for column in df:
    if plotnumber <=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.violinplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
The target or Average Price has a violin plot thicker in region 1.0 to 1.5 indicating max price between these 2 values.
The rest of the curves show a flattend voilin plot except some thickness at the 0 to 0.3 values.

# %% [markdown]
# # BOXPLOTS FOR OUTLIER DETECTION

# %%
plt.figure(figsize=(15, 15))
plotnumber=1
for i in numerical_col:
    if plotnumber<=27:
        plt.subplot(7, 6, plotnumber)
        df.boxplot([i])
    plotnumber+=1
plt.show()

# %%
attributes=df[['AveragePrice','Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags']]

# %%
from scipy.stats import zscore
z=np.abs(zscore(attributes))
z
# Out:
#             AveragePrice  Total Volume      4046      4225      4770  \
# Date
# 2015-12-27      0.188689      0.227716  0.230816  0.199902  0.212091
# 2015-12-20      0.139020      0.230427  0.231103  0.208054  0.211997
# 2015-12-13      1.182069      0.212085  0.231007  0.154478  0.211325
# 2015-12-06      0.809551      0.223444  0.230741  0.185350  0.211864
# 2015-11-29      0.312861      0.231538  0.230891  0.208719  0.211834
# ...                  ...           ...       ...       ...       ...
# 2018-02-04      0.556347      0.241373  0.230017  0.243857  0.212540
# 2018-01-28      0.755023      0.242296  0.230693  0.242277  0.212540
# 2018-01-21      1.152375      0.242331  0.230693  0.243090  0.205766
# 2018-01-14      1.301382      0.241625  0.230428  0.242651  0.205774
# 2018-01-07      0.531512      0.241253  0.229347  0.243170  0.210450
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags
# Date
# 2015-12-27    0.234170    0.232647    0.222352      0.17558
# ...

# %%
np.where(z>3)
# Out:
# (array([  346,   359,   780, ..., 17304, 17402, 17428], dtype=int64),
#  array([2, 2, 8, ..., 0, 0, 0], dtype=int64))

# %%
z.iloc[346, 2]
# Out:
# 3.199410614794124

# %%
df1=df[(z<3).all(axis=1)]

# %%
df1.shape
# Out:
# (17651, 12)

# %%
df.shape
# Out:
# (18249, 12)

# %%
print("Old Dataframe", df.shape[0])
print("New Dataframe", df1.shape[0])
print("DataLoss percentage:", ((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Old Dataframe 18249
# New Dataframe 17651
# DataLoss percentage: 3.276891884486821

# %% [markdown]
# There is 3% dataloss, so we can go ahead wtih the loss

# %%
q1=attributes.quantile(0.25)
q3=attributes.quantile(0.75)
IQR=q3-q1

# %%
df2=df[-((df<(q1-1.5*IQR))|(df>(q3+1.5*IQR))).any(axis=1)]

# %%
df2.shape
# Out:
# (11747, 12)

# %%
print("Old Dataframe", df.shape[0])
print("New Dataframe", df2.shape[0])
print("DataLoss percentage:", ((df.shape[0]-df2.shape[0])/df.shape[0])*100)
# Out:
# Old Dataframe 18249
# New Dataframe 11747
# DataLoss percentage: 35.62934955340019

# %%
We can go ahead with the zscore method with 3% data loss compared to IQR method

# %%
df=df1

# %%
plt.figure(figsize=(20, 25))
p=1
for i in numerical_col:
    if p<=23:
        plt.subplot(8, 4 , p)
        sns.scatterplot(x='AveragePrice', y=i, data=df, palette ='bright')
        plt.xlabel('AveragePrice')
        plt.ylabel(i)
    p+=1
plt.show()

# %%
All the numerical variables have a right-sided skewed curve other than year in relationship to the target variable.

# %% [markdown]
# # Linear Model Plots

# %%
sns.lmplot(x='AveragePrice', y='Large Bags', data=df)

# %%
Large Bags and Average Price have a negative correlation but most data points pass through the best line of fit.

# %%
sns.lmplot(x='AveragePrice', y='Total Volume', data=df)

# %% [markdown]
# Total volume and average price also are negative correlated but total volume has a major impact on average price

# %% [markdown]
# # CHECKING FOR DISTRIBUTIN OF DATA FOR SKEWNESS

# %%
plt.figure (figsize=(20, 25), facecolor='green') #despite the fact that distplot will be depricated, am trying out this. 
plotnumber=1
for column in numerical_col:
    if plotnumber<=18:
        ax=plt.subplot(6,4, plotnumber)
        sns.distplot(df[column], color='b')
        plt.xlabel(column, fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# Again we can note that all the curve show a right-sided skewness except Target and year variables.

# %%
df.skew()
# Out:
# AveragePrice    0.377432
# Total Volume    3.767138
# 4046            4.909848
# 4225            4.455745
# 4770            5.117170
# Total Bags      4.066771
# Small Bags      4.222706
# Large Bags      5.053434
# XLarge Bags     6.135607
# year            0.229976
# dtype: float64

# %% [markdown]
# There is major skewness to all the variables except target, which we will not remove. The year column also has no skewness.

# %%
skew=['Total Volume', '4046','4225', '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'Large Bags', 'XLarge Bags']

# %%
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')
df[skew] = scaler.fit_transform(df[skew].values)

# %%
df.skew()
# Out:
# AveragePrice    0.377432
# Total Volume   -0.008642
# 4046           -0.039282
# 4225           -0.044675
# 4770            0.024168
# Total Bags     -0.022204
# Small Bags     -0.024405
# Large Bags     -0.110913
# XLarge Bags     0.853758
# year            0.229976
# dtype: float64

# %% [markdown]
# Skewness is almost completely removed from all the columns except XLArge Bags

# %%
df.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.579895 -0.555432 -0.454277 -0.493640
# Total Volume     -0.579895      1.000000  0.890219  0.926118  0.819103
# 4046             -0.555432      0.890219  1.000000  0.765256  0.737604
# 4225             -0.454277      0.926118  0.765256  1.000000  0.797853
# 4770             -0.493640      0.819103  0.737604  0.797853  1.000000
# Total Bags       -0.563082      0.942190  0.803216  0.824134  0.761496
# Small Bags       -0.489354      0.907892  0.782053  0.791364  0.754142
# Large Bags       -0.485199      0.689720  0.611689  0.620794  0.550602
# XLarge Bags       0.011883      0.315526  0.217205  0.293793  0.284648
# year              0.091704      0.079419  0.001296 -0.002265 -0.049972
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      year
# AveragePrice   -0.563082   -0.489354   -0.485199     0.011883  0.091704
# ...

# %%
corr_hmap=df.corr()
plt.figure(figsize=(10, 9))
sns.heatmap(corr_hmap, annot=True, fmt='0.2f', cmap='Spectral')
plt.xlabel("Figure", fontsize=15)
plt.ylabel("Feature Names", fontsize=15)
plt.title("Descriptive Graph", fontsize=20)
plt.show()

# %% [markdown]
# Average Price is negatively correlated with 4770 and Small Bags with same values. So there is multicollinearity issue here.
# Total volume is negatively correlated wtih average price but positively related with almost all variables.
# Again 4046 is -vely related with average price and positively correlated with all variables except with date which is neutral.
# Remaining all variables are -vely correlated wtih Average Price and positively related with other varibles.
# Total bags and small bags are also hightly correlated with each other.

# %% [markdown]
# # Splitting x data and y label
# Applying LabelEncoder to convert string columns into float datatype and scaling the data¶

# %%
df.drop(['region', '4046', '4225','4770'], axis=1, inplace=True) #Dropping these columns which do not yeild to dataset

# %%
x=df.iloc[:,1:]
x
# Out:
#             Total Volume  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-12-27     -0.075324   -0.537507   -0.347421   -0.781153    -0.677919
# 2015-12-20     -0.147497   -0.498128   -0.311322   -0.771198    -0.677919
# 2015-12-13      0.205556   -0.566369   -0.374453   -0.758523    -0.677919
# 2015-12-06      0.019655   -0.713068   -0.510991   -0.699123    -0.677919
# 2015-11-29     -0.180674   -0.686312   -0.490534   -0.607027    -0.677919
# ...                  ...         ...         ...         ...          ...
# 2018-02-04     -0.678214   -0.340422   -0.175753   -0.412401    -0.677919
# 2018-01-28     -0.771326   -0.509513   -0.331971   -0.484991    -0.677919
# 2018-01-21     -0.775274   -0.503366   -0.313756   -0.950743    -0.677919
# 2018-01-14     -0.701797   -0.434176   -0.250408   -0.916068    -0.677919
# 2018-01-07     -0.667381   -0.393236   -0.211755   -1.048116    -0.677919
#
#                     type  year
# Date
# 2015-12-27  conventional  2015
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df['type']=le.fit_transform(df['type'])
df
# Out:
#             AveragePrice  Total Volume  Total Bags  Small Bags  Large Bags  \
# Date
# 2015-12-27          1.33     -0.075324   -0.537507   -0.347421   -0.781153
# 2015-12-20          1.35     -0.147497   -0.498128   -0.311322   -0.771198
# 2015-12-13          0.93      0.205556   -0.566369   -0.374453   -0.758523
# 2015-12-06          1.08      0.019655   -0.713068   -0.510991   -0.699123
# 2015-11-29          1.28     -0.180674   -0.686312   -0.490534   -0.607027
# ...                  ...           ...         ...         ...         ...
# 2018-02-04          1.63     -0.678214   -0.340422   -0.175753   -0.412401
# 2018-01-28          1.71     -0.771326   -0.509513   -0.331971   -0.484991
# 2018-01-21          1.87     -0.775274   -0.503366   -0.313756   -0.950743
# 2018-01-14          1.93     -0.701797   -0.434176   -0.250408   -0.916068
# 2018-01-07          1.62     -0.667381   -0.393236   -0.211755   -1.048116
#
#             XLarge Bags  type  year
# Date
# ...

# %%
x=df.iloc[:,1:]
x
# Out:
#             Total Volume  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-12-27     -0.075324   -0.537507   -0.347421   -0.781153    -0.677919
# 2015-12-20     -0.147497   -0.498128   -0.311322   -0.771198    -0.677919
# 2015-12-13      0.205556   -0.566369   -0.374453   -0.758523    -0.677919
# 2015-12-06      0.019655   -0.713068   -0.510991   -0.699123    -0.677919
# 2015-11-29     -0.180674   -0.686312   -0.490534   -0.607027    -0.677919
# ...                  ...         ...         ...         ...          ...
# 2018-02-04     -0.678214   -0.340422   -0.175753   -0.412401    -0.677919
# 2018-01-28     -0.771326   -0.509513   -0.331971   -0.484991    -0.677919
# 2018-01-21     -0.775274   -0.503366   -0.313756   -0.950743    -0.677919
# 2018-01-14     -0.701797   -0.434176   -0.250408   -0.916068    -0.677919
# 2018-01-07     -0.667381   -0.393236   -0.211755   -1.048116    -0.677919
#
#             type  year
# Date
# 2015-12-27     0  2015
# ...

# %%
from sklearn.preprocessing import StandardScaler
st=StandardScaler() #scaling applied and we can see the uniformity in the values
x=pd.DataFrame(st.fit_transform(x))
x
# Out:
#               0         1         2         3         4         5         6
# 0     -0.075324 -0.537507 -0.347421 -0.781153 -0.677919 -1.019047 -1.210013
# 1     -0.147497 -0.498128 -0.311322 -0.771198 -0.677919 -1.019047 -1.210013
# 2      0.205556 -0.566369 -0.374453 -0.758523 -0.677919 -1.019047 -1.210013
# 3      0.019655 -0.713068 -0.510991 -0.699123 -0.677919 -1.019047 -1.210013
# 4     -0.180674 -0.686312 -0.490534 -0.607027 -0.677919 -1.019047 -1.210013
# ...         ...       ...       ...       ...       ...       ...       ...
# 17646 -0.678214 -0.340422 -0.175753 -0.412401 -0.677919  0.981309  1.980756
# 17647 -0.771326 -0.509513 -0.331971 -0.484991 -0.677919  0.981309  1.980756
# 17648 -0.775274 -0.503366 -0.313756 -0.950743 -0.677919  0.981309  1.980756
# 17649 -0.701797 -0.434176 -0.250408 -0.916068 -0.677919  0.981309  1.980756
# 17650 -0.667381 -0.393236 -0.211755 -1.048116 -0.677919  0.981309  1.980756
#
# [17651 rows x 7 columns]

# %% [markdown]
# # Applying Variation inflation Factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
VIF=pd.DataFrame()
VIF["VIF values"]=[variance_inflation_factor(x.values, i) for i in range (len(x.columns))]
VIF["features"]=x.columns
VIF
# Out:
#    VIF values  features
# 0   12.966504         0
# 1   29.681056         1
# 2   16.231762         2
# 3    3.331621         3
# 4    1.976834         4
# 5    3.325392         5
# 6    1.249782         6

# %%
Total bags has highest VIF factor. so we are going to drop it to reduce VIF overall.

# %%
df.drop(['Total Bags'], axis=1, inplace=True)

# %%
x=df.iloc[:,1:]
x
# Out:
#             Total Volume  Small Bags  Large Bags  XLarge Bags  type  year
# Date
# 2015-12-27     -0.075324   -0.347421   -0.781153    -0.677919     0  2015
# 2015-12-20     -0.147497   -0.311322   -0.771198    -0.677919     0  2015
# 2015-12-13      0.205556   -0.374453   -0.758523    -0.677919     0  2015
# 2015-12-06      0.019655   -0.510991   -0.699123    -0.677919     0  2015
# 2015-11-29     -0.180674   -0.490534   -0.607027    -0.677919     0  2015
# ...                  ...         ...         ...          ...   ...   ...
# 2018-02-04     -0.678214   -0.175753   -0.412401    -0.677919     1  2018
# 2018-01-28     -0.771326   -0.331971   -0.484991    -0.677919     1  2018
# 2018-01-21     -0.775274   -0.313756   -0.950743    -0.677919     1  2018
# 2018-01-14     -0.701797   -0.250408   -0.916068    -0.677919     1  2018
# 2018-01-07     -0.667381   -0.211755   -1.048116    -0.677919     1  2018
#
# [17651 rows x 6 columns]

# %%
from sklearn.preprocessing import StandardScaler
st=StandardScaler() #scaling applied and we can see the uniformity in the values
x=pd.DataFrame(st.fit_transform(x))
x
# Out:
#               0         1         2         3         4         5
# 0     -0.075324 -0.347421 -0.781153 -0.677919 -1.019047 -1.210013
# 1     -0.147497 -0.311322 -0.771198 -0.677919 -1.019047 -1.210013
# 2      0.205556 -0.374453 -0.758523 -0.677919 -1.019047 -1.210013
# 3      0.019655 -0.510991 -0.699123 -0.677919 -1.019047 -1.210013
# 4     -0.180674 -0.490534 -0.607027 -0.677919 -1.019047 -1.210013
# ...         ...       ...       ...       ...       ...       ...
# 17646 -0.678214 -0.175753 -0.412401 -0.677919  0.981309  1.980756
# 17647 -0.771326 -0.331971 -0.484991 -0.677919  0.981309  1.980756
# 17648 -0.775274 -0.313756 -0.950743 -0.677919  0.981309  1.980756
# 17649 -0.701797 -0.250408 -0.916068 -0.677919  0.981309  1.980756
# 17650 -0.667381 -0.211755 -1.048116 -0.677919  0.981309  1.980756
#
# [17651 rows x 6 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
VIF=pd.DataFrame()
VIF["VIF values"]=[variance_inflation_factor(x.values, i) for i in range (len(x.columns))]
VIF["features"]=x.columns
VIF
# Out:
#    VIF values  features
# 0   10.210514         0
# 1    6.418406         1
# 2    2.075431         2
# 3    1.976484         3
# 4    3.293811         4
# 5    1.198288         5

# %% [markdown]
# VIF has been reduced to our value of 10 for all columns

# %% [markdown]
# # Finding the best score on random_state value and fitting for training and testing data

# %%
y=df.iloc[:, 0]
y
# Out:
# Date
# 2015-12-27    1.33
# 2015-12-20    1.35
# 2015-12-13    0.93
# 2015-12-06    1.08
# 2015-11-29    1.28
#               ...
# 2018-02-04    1.63
# 2018-01-28    1.71
# 2018-01-21    1.87
# 2018-01-14    1.93
# 2018-01-07    1.62
# Name: AveragePrice, Length: 17651, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso, Ridge
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.model_selection import train_test_split

# %%
maxAcc=0
maxRS=0
for i in range(1, 200):
    x_train,x_test,y_train,y_test=train_test_split(x, y, test_size=.30, random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test, pred)
    if acc>maxAcc:
        maxAcc=acc
        maxRS=i
print("Maximum r2_score is:", maxAcc, "on Random_State", maxRS)
# Out:
# Maximum r2_score is: 0.45979139772553235 on Random_State 196

# %% [markdown]
# Best random_state is 196 with a score of 45%.

# %% [markdown]
# # Training the data on random score of 196

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=.30, random_state=maxRS)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso, Ridge
from sklearn.svm import SVR

# %%
x_train.shape
# Out:
# (12355, 6)

# %%
x_test.shape
# Out:
# (5296, 6)

# %%
y_train.shape
# Out:
# (12355,)

# %%
y_test.shape
# Out:
# (5296,)

# %%
lg=LinearRegression()
lg.fit(x_train,y_train)
lg.score(x_train,y_train)
pred_lg=lg.predict(x_test)
print(r2_score(y_test, pred_lg))
print("Error:")
print("Mean squared error:", mean_squared_error(y_test, pred_lg))
print("Mean_absolute_error", mean_absolute_error(y_test, pred_lg))
print("Root_mean_Squared_error:", np.sqrt(mean_squared_error(y_test, pred_lg)))
# Out:
# 0.45979139772553235
# Error:
# Mean squared error: 0.08053323063414777
# Mean_absolute_error 0.22346014648356777
# Root_mean_Squared_error: 0.28378377443777114

# %%
rfr=RandomForestRegressor()
rfr.fit(x_train, y_train)
pred_rfr=rfr.predict(x_test) 
pred_train=rfr.predict(x_train)
print('R2_score', r2_score(y_test, pred_rfr))
print('R2_score on training data', r2_score(y_train, pred_train)*100)
print("Mean squared error:", mean_squared_error(y_test, pred_rfr))
print("Mean_absolute_error", mean_absolute_error(y_test, pred_rfr))
print("Root_mean_Squared_error:", np.sqrt(mean_squared_error(y_test, pred_rfr)))
# Out:
# R2_score 0.6880297806810179
# R2_score on training data 95.50144825266436
# Mean squared error: 0.04650790364614803
# Mean_absolute_error 0.1545706004531722
# Root_mean_Squared_error: 0.21565691189050265

# %%
knn=KNN()
knn.fit(x_train, y_train)
pred_knn=rfr.predict(x_test) 
pred_train=knn.predict(x_train)
print('R2_score', r2_score(y_test, pred_knn))
print('R2_score on training data', r2_score(y_train, pred_train)*100)
print("Mean squared error:", mean_squared_error(y_test, pred_knn))
print("Mean_absolute_error", mean_absolute_error(y_test, pred_knn))
print("Root_mean_Squared_error:", np.sqrt(mean_squared_error(y_test, pred_knn)))
# Out:
# R2_score 0.6880297806810179
# R2_score on training data 77.38401146176044
# Mean squared error: 0.04650790364614803
# Mean_absolute_error 0.1545706004531722
# Root_mean_Squared_error: 0.21565691189050265

# %%
dtc=DecisionTreeRegressor()
dtc.fit(x_train, y_train)
pred_dtc=dtc.predict(x_test) 
pred_train=dtc.predict(x_train)
print('R2_score', r2_score(y_test, pred_dtc))
print('R2_score on training data', r2_score(y_train, pred_train)*100)
print("Mean squared error:", mean_squared_error(y_test, pred_dtc))
print("Mean_absolute_error", mean_absolute_error(y_test, pred_dtc))
print("Root_mean_Squared_error:", np.sqrt(mean_squared_error(y_test, pred_dtc)))
# Out:
# R2_score 0.4251923919603069
# R2_score on training data 100.0
# Mean squared error: 0.08569118202416919
# Mean_absolute_error 0.20048527190332327
# Root_mean_Squared_error: 0.2927305621628346

# %%
from sklearn.ensemble import  GradientBoostingRegressor
gbr=GradientBoostingRegressor()
gbr.fit(x_train, y_train)
pred_gbr=dtc.predict(x_test) 
pred_train=dtc.predict(x_train)
print('R2_score', r2_score(y_test, pred_gbr))
print('R2_score on training data', r2_score(y_train, pred_train)*100)
print("Mean squared error:", mean_squared_error(y_test, pred_gbr))
print("Mean_absolute_error", mean_absolute_error(y_test, pred_gbr))
print("Root_mean_Squared_error:", np.sqrt(mean_squared_error(y_test, pred_gbr)))
# Out:
# R2_score 0.4251923919603069
# R2_score on training data 100.0
# Mean squared error: 0.08569118202416919
# Mean_absolute_error 0.20048527190332327
# Root_mean_Squared_error: 0.2927305621628346

# %%
la=Lasso()
la.fit(x_train, y_train)
pred_la=la.predict(x_test) 
pred_train=la.predict(x_train)
print('R2_score', r2_score(y_test, pred_la))
print('R2_score on training data', r2_score(y_train, pred_train)*100)
print("Mean squared error:", mean_squared_error(y_test, pred_la))
print("Mean_absolute_error", mean_absolute_error(y_test, pred_la))
print("Root_mean_Squared_error:", np.sqrt(mean_squared_error(y_test, pred_la)))
# Out:
# R2_score -3.198533512049906e-05
# R2_score on training data 0.0
# Mean squared error: 0.14908279167979546
# Mean_absolute_error 0.3173499951399986
# Root_mean_Squared_error: 0.38611240808836417

# %%
svr=SVR()
svr.fit(x_train, y_train)
pred_svr=svr.predict(x_test) 
pred_train=dtc.predict(x_train)
print('R2_score', r2_score(y_test, pred_svr))
print('R2_score on training data', r2_score(y_train, pred_train)*100)
print("Mean squared error:", mean_squared_error(y_test, pred_svr))
print("Mean_absolute_error", mean_absolute_error(y_test, pred_svr))
print("Root_mean_Squared_error:", np.sqrt(mean_squared_error(y_test, pred_svr)))
# Out:
# R2_score 0.5911913311140122
# R2_score on training data 100.0
# Mean squared error: 0.0609443882937409
# Mean_absolute_error 0.18697895593857364
# Root_mean_Squared_error: 0.24686917242487144

# %%
rd=Ridge()
rd.fit(x_train, y_train)
pred_rd=rd.predict(x_test) 
pred_train=rd.predict(x_train)
print('R2_score', r2_score(y_test, pred_rd))
print('R2_score on training data', r2_score(y_train, pred_train)*100)
print("Mean squared error:", mean_squared_error(y_test, pred_rd))
print("Mean_absolute_error", mean_absolute_error(y_test, pred_rd))
print("Root_mean_Squared_error:", np.sqrt(mean_squared_error(y_test, pred_rd)))
# Out:
# R2_score 0.459793069010334
# R2_score on training data 43.36322149394969
# Mean squared error: 0.08053298148231305
# Mean_absolute_error 0.22346043609349062
# Root_mean_Squared_error: 0.28378333545561313

# %% [markdown]
# # Cross validation score

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(lg, x, y, cv=5, scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 Score and cross validation score is:", (r2_score(y_test, pred_lg)-score.mean())*100)
# Out:
# [-0.23528528  0.0036279   0.41017715  0.05594701  0.05649156]
# 0.058191668463409375
# Difference between R2 Score and cross validation score is: 40.1599729262123

# %%
score1=cross_val_score(rfr, x, y, cv=5, scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 Score and cross validation score is:", (r2_score(y_test, pred_rfr)-score.mean())*100)
# Out:
# [-0.23528528  0.0036279   0.41017715  0.05594701  0.05649156]
# 0.058191668463409375
# Difference between R2 Score and cross validation score is: 62.98381122176085

# %%
score2=cross_val_score(knn, x, y, cv=5)
print(score)
print(score.mean())
print("Difference between R2 Score and cross validation score is:", (r2_score(y_test, pred_knn)-score.mean())*100)
# Out:
# [-0.23528528  0.0036279   0.41017715  0.05594701  0.05649156]
# 0.058191668463409375
# Difference between R2 Score and cross validation score is: 62.98381122176085

# %%
score3=cross_val_score(rfr, x, y, cv=5)
print(score)
print(score.mean())
print("Difference between R2 Score and cross validation score is -", (r2_score(y_test, pred_rfr)-score.mean())*100)
# Out:
# [-0.23528528  0.0036279   0.41017715  0.05594701  0.05649156]
# 0.058191668463409375
# Difference between R2 Score and cross validation score is - 62.98381122176085

# %%
score3=cross_val_score(rfr, x, y, cv=5)
print(score)
print(score.mean())
print("Difference between R2 Score and cross validation score is -", (r2_score(y_test, pred_rfr)-score.mean())*100)
# Out:
# [-0.23528528  0.0036279   0.41017715  0.05594701  0.05649156]
# 0.058191668463409375
# Difference between R2 Score and cross validation score is - 62.98381122176085

# %%
score4=cross_val_score(dtc, x, y, cv=5)
print(score)
print(score.mean())
print("Difference between R2 Score and cross validation score is:", (r2_score(y_test, pred_dtc)-score.mean())*100)
# Out:
# [-0.23528528  0.0036279   0.41017715  0.05594701  0.05649156]
# 0.058191668463409375
# Difference between R2 Score and cross validation score is: 36.70007234968975

# %%
score5=cross_val_score(gbr, x, y, cv=5)
print(score)
print(score.mean())
print("Difference between R2 Score and cross validation score is:", (r2_score(y_test, pred_gbr)-score.mean())*100)
# Out:
# [-0.23528528  0.0036279   0.41017715  0.05594701  0.05649156]
# 0.058191668463409375
# Difference between R2 Score and cross validation score is: 36.70007234968975

# %%
score6=cross_val_score(la, x, y, cv=5)
print(score)
print(score.mean())
print("Difference between R2 Score and cross validation score is:", (r2_score(y_test, pred_la)-score.mean())*100)
# Out:
# [-0.23528528  0.0036279   0.41017715  0.05594701  0.05649156]
# 0.058191668463409375
# Difference between R2 Score and cross validation score is: -5.822365379852988

# %%
score7=cross_val_score(rd, x, y, cv=5)
print(score)
print(score.mean())
print("Difference between R2 Score and cross validation score is:", (r2_score(y_test, pred_rd)-score.mean())*100)
# Out:
# [-0.23528528  0.0036279   0.41017715  0.05594701  0.05649156]
# 0.058191668463409375
# Difference between R2 Score and cross validation score is: 40.16014005469246

# %%
score8=cross_val_score(svr, x, y, cv=5)
print(score)
print(score.mean())
print("Difference between R2 Score and cross validation score is:", (r2_score(y_test, pred_svr)-score.mean())*100)
# Out:
# [-0.23528528  0.0036279   0.41017715  0.05594701  0.05649156]
# 0.058191668463409375
# Difference between R2 Score and cross validation score is: 53.299966265060284
